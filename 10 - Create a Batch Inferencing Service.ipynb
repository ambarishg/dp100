# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep-native 24.0.0 (c:\applications\anaconda\lib\site-packages), Requirement.parse('azureml-dataprep-native<39.0.0,>=38.0.0'), {'azureml-dataprep'}).
# Ready to use Azure ML 1.33.0 to work with wsag

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8896666666666667
# AUC: 0.8792900144285785
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure',
                   'TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data\10.csv
# Uploaded batch-data\10.csv, 1 files out of an estimated total of 100
# Uploading batch-data\100.csv
# Uploaded batch-data\100.csv, 2 files out of an estimated total of 100
# Uploading batch-data\11.csv
# Uploaded batch-data\11.csv, 3 files out of an estimated total of 100
# Uploading batch-data\12.csv
# Uploaded batch-data\12.csv, 4 files out of an estimated total of 100
# Uploading batch-data\13.csv
# Uploaded batch-data\13.csv, 5 files out of an estimated total of 100
# Uploading batch-data\14.csv
# Uploaded batch-data\14.csv, 6 files out of an estimated total of 100
# Uploading batch-data\15.csv
# Uploaded batch-data\15.csv, 7 files out of an estimated total of 100
# Uploading batch-data\16.csv
# Uploaded batch-data\16.csv, 8 files out of an estimated total of 100
# Uploading batch-data\17.csv
# Uploaded batch-data\17.csv, 9 files out of an estimated total of 100
# Uploading batch-data\18.csv
# Uploaded batch-data\18.csv, 10 files out of an estimated total of 100
# Uploading batch-data\19.csv
# Uploaded batch-data\19.csv, 11 files out of an estimated total of 100
# Uploading batch-data\20.csv
# Uploaded batch-data\20.csv, 12 files out of an estimated total of 100
# Uploading batch-data\21.csv
# Uploaded batch-data\21.csv, 13 files out of an estimated total of 100
# Uploading batch-data\22.csv
# Uploaded batch-data\22.csv, 14 files out of an estimated total of 100
# Uploading batch-data\23.csv
# Uploaded batch-data\23.csv, 15 files out of an estimated total of 100
# Uploading batch-data\24.csv
# Uploaded batch-data\24.csv, 16 files out of an estimated total of 100
# Uploading batch-data\25.csv
# Uploaded batch-data\25.csv, 17 files out of an estimated total of 100
# Uploading batch-data\26.csv
# Uploaded batch-data\26.csv, 18 files out of an estimated total of 100
# Uploading batch-data\27.csv
# Uploaded batch-data\27.csv, 19 files out of an estimated total of 100
# Uploading batch-data\28.csv
# Uploaded batch-data\28.csv, 20 files out of an estimated total of 100
# Uploading batch-data\29.csv
# Uploaded batch-data\29.csv, 21 files out of an estimated total of 100
# Uploading batch-data\2.csv
# Uploaded batch-data\2.csv, 22 files out of an estimated total of 100
# Uploading batch-data\3.csv
# Uploaded batch-data\3.csv, 23 files out of an estimated total of 100
# Uploading batch-data\30.csv
# Uploaded batch-data\30.csv, 24 files out of an estimated total of 100
# Uploading batch-data\31.csv
# Uploaded batch-data\31.csv, 25 files out of an estimated total of 100
# Uploading batch-data\32.csv
# Uploaded batch-data\32.csv, 26 files out of an estimated total of 100
# Uploading batch-data\33.csv
# Uploaded batch-data\33.csv, 27 files out of an estimated total of 100
# Uploading batch-data\34.csv
# Uploaded batch-data\34.csv, 28 files out of an estimated total of 100
# Uploading batch-data\35.csv
# Uploaded batch-data\35.csv, 29 files out of an estimated total of 100
# Uploading batch-data\36.csv
# Uploaded batch-data\36.csv, 30 files out of an estimated total of 100
# Uploading batch-data\37.csv
# Uploaded batch-data\37.csv, 31 files out of an estimated total of 100
# Uploading batch-data\38.csv
# Uploaded batch-data\38.csv, 32 files out of an estimated total of 100
# Uploading batch-data\39.csv
# Uploaded batch-data\39.csv, 33 files out of an estimated total of 100
# Uploading batch-data\4.csv
# Uploaded batch-data\4.csv, 34 files out of an estimated total of 100
# Uploading batch-data\40.csv
# Uploaded batch-data\40.csv, 35 files out of an estimated total of 100
# Uploading batch-data\41.csv
# Uploaded batch-data\41.csv, 36 files out of an estimated total of 100
# Uploading batch-data\42.csv
# Uploaded batch-data\42.csv, 37 files out of an estimated total of 100
# Uploading batch-data\43.csv
# Uploaded batch-data\43.csv, 38 files out of an estimated total of 100
# Uploading batch-data\44.csv
# Uploaded batch-data\44.csv, 39 files out of an estimated total of 100
# Uploading batch-data\45.csv
# Uploaded batch-data\45.csv, 40 files out of an estimated total of 100
# Uploading batch-data\46.csv
# Uploaded batch-data\46.csv, 41 files out of an estimated total of 100
# Uploading batch-data\47.csv
# Uploaded batch-data\47.csv, 42 files out of an estimated total of 100
# Uploading batch-data\48.csv
# Uploaded batch-data\48.csv, 43 files out of an estimated total of 100
# Uploading batch-data\49.csv
# Uploaded batch-data\49.csv, 44 files out of an estimated total of 100
# Uploading batch-data\5.csv
# Uploaded batch-data\5.csv, 45 files out of an estimated total of 100
# Uploading batch-data\50.csv
# Uploaded batch-data\50.csv, 46 files out of an estimated total of 100
# Uploading batch-data\51.csv
# Uploaded batch-data\51.csv, 47 files out of an estimated total of 100
# Uploading batch-data\52.csv
# Uploaded batch-data\52.csv, 48 files out of an estimated total of 100
# Uploading batch-data\53.csv
# Uploaded batch-data\53.csv, 49 files out of an estimated total of 100
# Uploading batch-data\54.csv
# Uploaded batch-data\54.csv, 50 files out of an estimated total of 100
# Uploading batch-data\55.csv
# Uploaded batch-data\55.csv, 51 files out of an estimated total of 100
# Uploading batch-data\56.csv
# Uploaded batch-data\56.csv, 52 files out of an estimated total of 100
# Uploading batch-data\57.csv
# Uploaded batch-data\57.csv, 53 files out of an estimated total of 100
# Uploading batch-data\1.csv
# Uploaded batch-data\1.csv, 54 files out of an estimated total of 100
# Uploading batch-data\58.csv
# Uploaded batch-data\58.csv, 55 files out of an estimated total of 100
# Uploading batch-data\59.csv
# Uploaded batch-data\59.csv, 56 files out of an estimated total of 100
# Uploading batch-data\6.csv
# Uploaded batch-data\6.csv, 57 files out of an estimated total of 100
# Uploading batch-data\60.csv
# Uploaded batch-data\60.csv, 58 files out of an estimated total of 100
# Uploading batch-data\61.csv
# Uploaded batch-data\61.csv, 59 files out of an estimated total of 100
# Uploading batch-data\62.csv
# Uploaded batch-data\62.csv, 60 files out of an estimated total of 100
# Uploading batch-data\63.csv
# Uploaded batch-data\63.csv, 61 files out of an estimated total of 100
# Uploading batch-data\64.csv
# Uploaded batch-data\64.csv, 62 files out of an estimated total of 100
# Uploading batch-data\65.csv
# Uploaded batch-data\65.csv, 63 files out of an estimated total of 100
# Uploading batch-data\66.csv
# Uploaded batch-data\66.csv, 64 files out of an estimated total of 100
# Uploading batch-data\67.csv
# Uploaded batch-data\67.csv, 65 files out of an estimated total of 100
# Uploading batch-data\68.csv
# Uploaded batch-data\68.csv, 66 files out of an estimated total of 100
# Uploading batch-data\69.csv
# Uploaded batch-data\69.csv, 67 files out of an estimated total of 100
# Uploading batch-data\7.csv
# Uploaded batch-data\7.csv, 68 files out of an estimated total of 100
# Uploading batch-data\70.csv
# Uploaded batch-data\70.csv, 69 files out of an estimated total of 100
# Uploading batch-data\71.csv
# Uploaded batch-data\71.csv, 70 files out of an estimated total of 100
# Uploading batch-data\72.csv
# Uploaded batch-data\72.csv, 71 files out of an estimated total of 100
# Uploading batch-data\73.csv
# Uploaded batch-data\73.csv, 72 files out of an estimated total of 100
# Uploading batch-data\74.csv
# Uploaded batch-data\74.csv, 73 files out of an estimated total of 100
# Uploading batch-data\75.csv
# Uploaded batch-data\75.csv, 74 files out of an estimated total of 100
# Uploading batch-data\76.csv
# Uploaded batch-data\76.csv, 75 files out of an estimated total of 100
# Uploading batch-data\77.csv
# Uploaded batch-data\77.csv, 76 files out of an estimated total of 100
# Uploading batch-data\78.csv
# Uploaded batch-data\78.csv, 77 files out of an estimated total of 100
# Uploading batch-data\79.csv
# Uploaded batch-data\79.csv, 78 files out of an estimated total of 100
# Uploading batch-data\8.csv
# Uploaded batch-data\8.csv, 79 files out of an estimated total of 100
# Uploading batch-data\80.csv
# Uploaded batch-data\80.csv, 80 files out of an estimated total of 100
# Uploading batch-data\81.csv
# Uploaded batch-data\81.csv, 81 files out of an estimated total of 100
# Uploading batch-data\82.csv
# Uploaded batch-data\82.csv, 82 files out of an estimated total of 100
# Uploading batch-data\83.csv
# Uploaded batch-data\83.csv, 83 files out of an estimated total of 100
# Uploading batch-data\84.csv
# Uploaded batch-data\84.csv, 84 files out of an estimated total of 100
# Uploading batch-data\85.csv
# Uploaded batch-data\85.csv, 85 files out of an estimated total of 100
# Uploading batch-data\86.csv
# Uploaded batch-data\86.csv, 86 files out of an estimated total of 100
# Uploading batch-data\87.csv
# Uploaded batch-data\87.csv, 87 files out of an estimated total of 100
# Uploading batch-data\88.csv
# Uploaded batch-data\88.csv, 88 files out of an estimated total of 100
# Uploading batch-data\89.csv
# Uploaded batch-data\89.csv, 89 files out of an estimated total of 100
# Uploading batch-data\9.csv
# Uploaded batch-data\9.csv, 90 files out of an estimated total of 100
# Uploading batch-data\90.csv
# Uploaded batch-data\90.csv, 91 files out of an estimated total of 100
# Uploading batch-data\91.csv
# Uploaded batch-data\91.csv, 92 files out of an estimated total of 100
# Uploading batch-data\92.csv
# Uploaded batch-data\92.csv, 93 files out of an estimated total of 100
# Uploading batch-data\93.csv
# Uploaded batch-data\93.csv, 94 files out of an estimated total of 100
# Uploading batch-data\94.csv
# Uploaded batch-data\94.csv, 95 files out of an estimated total of 100
# Uploading batch-data\95.csv
# Uploaded batch-data\95.csv, 96 files out of an estimated total of 100
# Uploading batch-data\96.csv
# Uploaded batch-data\96.csv, 97 files out of an estimated total of 100
# Uploading batch-data\97.csv
# Uploaded batch-data\97.csv, 98 files out of an estimated total of 100
# Uploading batch-data\98.csv
# Uploaded batch-data\98.csv, 99 files out of an estimated total of 100
# Uploading batch-data\99.csv
# Uploaded batch-data\99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "agcluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# InProgress.....
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Overwriting batch_pipeline/batch_diabetes.py

# %% [markdown]
# The pipeline will need an environment in which to run, so we'll create a Conda specification that includes the packages that the code uses.

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Overwriting batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Create an Environment for the experiment
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %%
# !pip install azureml-pipeline
# Out:
# Requirement already satisfied: azureml-pipeline in c:\applications\anaconda\lib\site-packages (1.33.0)
# Requirement already satisfied: azureml-pipeline-core~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-pipeline-steps~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-core~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: SecretStorage<4.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (3.3.1)
# Requirement already satisfied: pathspec<1.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.7.0)
# Requirement already satisfied: msrest<1.0.0,>=0.5.1 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.6.21)
# Requirement already satisfied: jmespath<1.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2.25.1)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (8.0.0)
# Requirement already satisfied: docker<5.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (4.4.4)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (3.3.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2.8.1)
# Requirement already satisfied: ruamel.yaml<0.17.5,>=0.15.35 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.17.4)
# Requirement already satisfied: PyJWT<3.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.7.1)
# Requirement already satisfied: azure-mgmt-keyvault<10.0.0,>=0.40.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (9.0.0)
# Requirement already satisfied: backports.tempfile in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.0)
# Requirement already satisfied: jsonpickle<3.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2.0.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.2.7)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.5.1)
# Requirement already satisfied: contextlib2<1.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.6.0.post1)
# Requirement already satisfied: pytz in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2021.1)
# Requirement already satisfied: urllib3<=1.26.5,>=1.23 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.25.11)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.61.1)
# Requirement already satisfied: azure-mgmt-authorization<1.0.0,>=0.40.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.61.0)
# Requirement already satisfied: azure-mgmt-resource<15.0.0,>=1.2.1 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (13.0.0)
# Requirement already satisfied: msrestazure<=0.6.4,>=0.4.33 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.6.4)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.1.27)
# Requirement already satisfied: azure-mgmt-storage<16.0.0,>=1.5.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (11.2.0)
# Requirement already satisfied: pyopenssl<21.0.0 in c:\applications\anaconda\lib\site-packages (from azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (19.1.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in c:\applications\anaconda\lib\site-packages (from azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.2.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.9.0 in c:\applications\anaconda\lib\site-packages (from azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.14.0)
# Requirement already satisfied: six>=1.11.0 in c:\applications\anaconda\lib\site-packages (from azure-core<2.0.0,>=1.9.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.15.0)
# Requirement already satisfied: azureml-train-core~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-train-automl-client~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-telemetry~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-automl-core~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-dataset-runtime~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: azureml-dataprep<2.21.0a,>=2.20.0a in c:\applications\anaconda\lib\site-packages (from azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (2.20.1)
# Requirement already satisfied: numpy!=1.19.4 in c:\applications\anaconda\lib\site-packages (from azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.18.5)
# Requirement already satisfied: pyarrow<4.0.0,>=0.17.0 in c:\applications\anaconda\lib\site-packages (from azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.0.1)
# Requirement already satisfied: cloudpickle<2.0.0,>=1.1.0 in c:\applications\anaconda\lib\site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.6.0)
# Requirement already satisfied: dotnetcore2<3.0.0,>=2.1.14 in c:\applications\anaconda\lib\site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (2.1.21)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Using cached azureml_dataprep_native-38.0.0-cp38-cp38-win_amd64.whl (897 kB)
# Requirement already satisfied: azure-identity<1.5.0,>=1.2.0 in c:\applications\anaconda\lib\site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.4.1)
# Collecting azureml-dataprep-rslex<1.19.0a,>=1.18.0dev0
#   Downloading azureml_dataprep_rslex-1.18.2-cp38-cp38-win_amd64.whl (8.7 MB)
# Requirement already satisfied: msal-extensions~=0.2.2 in c:\applications\anaconda\lib\site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (0.2.2)
# Requirement already satisfied: msal<2.0.0,>=1.3.0 in c:\applications\anaconda\lib\site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.13.0)
# Requirement already satisfied: applicationinsights in c:\applications\anaconda\lib\site-packages (from azureml-telemetry~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (0.11.10)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.33.0 in c:\applications\anaconda\lib\site-packages (from azureml-train-core~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.33.0)
# Requirement already satisfied: cffi>=1.12 in c:\applications\anaconda\lib\site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.14.5)
# Requirement already satisfied: pycparser in c:\applications\anaconda\lib\site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2.20)
# Requirement already satisfied: pywin32==227 in c:\applications\anaconda\lib\site-packages (from docker<5.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (227)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\applications\anaconda\lib\site-packages (from docker<5.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.0.1)
# Requirement already satisfied: distro>=1.2.0 in c:\applications\anaconda\lib\site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.6.0)
# Requirement already satisfied: portalocker~=1.6 in c:\applications\anaconda\lib\site-packages (from msal-extensions~=0.2.2->azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime~=1.33.0->azureml-train-automl-client~=1.33.0->azureml-pipeline-steps~=1.33.0->azureml-pipeline) (1.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\applications\anaconda\lib\site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2020.12.5)
# Requirement already satisfied: isodate>=0.6.0 in c:\applications\anaconda\lib\site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\applications\anaconda\lib\site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.1 in c:\applications\anaconda\lib\site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\applications\anaconda\lib\site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\applications\anaconda\lib\site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\applications\anaconda\lib\site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (3.1.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\applications\anaconda\lib\site-packages (from ruamel.yaml<0.17.5,>=0.15.35->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.2.2)
# Requirement already satisfied: jeepney>=0.6 in c:\applications\anaconda\lib\site-packages (from SecretStorage<4.0.0->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (0.6.0)
# Requirement already satisfied: backports.weakref in c:\applications\anaconda\lib\site-packages (from backports.tempfile->azureml-core~=1.33.0->azureml-pipeline-core~=1.33.0->azureml-pipeline) (1.0.post1)
# Installing collected packages: azureml-dataprep-rslex, azureml-dataprep-native
#   Attempting uninstall: azureml-dataprep-rslex
#     Found existing installation: azureml-dataprep-rslex 1.2.3
#     Uninstalling azureml-dataprep-rslex-1.2.3:
#       Successfully uninstalled azureml-dataprep-rslex-1.2.3
#   Attempting uninstall: azureml-dataprep-native
#     Found existing installation: azureml-dataprep-native 24.0.0
#     Uninstalling azureml-dataprep-native-24.0.0:
#       Successfully uninstalled azureml-dataprep-native-24.0.0
# Successfully installed azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.18.2

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig
from azureml.core.runconfig import DockerConfiguration

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [7f1e08d1][e3e3e332-61b9-4c4f-a2e1-7af760d268fd], (This step will run and generate new outputs)
# Submitted PipelineRun a4786afb-5e0a-4b07-8b96-36aa53b5b350
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a4786afb-5e0a-4b07-8b96-36aa53b5b350?wsid=/subscriptions/6ea869be-bab3-4204-94c3-1fc677f7d2de/resourcegroups/rgag/workspaces/wsag&tid=0f942ca0-ebef-4f26-80f8-f501d599ba90
# PipelineRunId: a4786afb-5e0a-4b07-8b96-36aa53b5b350
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/a4786afb-5e0a-4b07-8b96-36aa53b5b350?wsid=/subscriptions/6ea869be-bab3-4204-94c3-1fc677f7d2de/resourcegroups/rgag/workspaces/wsag&tid=0f942ca0-ebef-4f26-80f8-f501d599ba90
# PipelineRun Status: Running
#
#
# StepRunId: 326a23de-f2a6-4093-bd2c-52b4b1f3fff2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/326a23de-f2a6-4093-bd2c-52b4b1f3fff2?wsid=/subscriptions/6ea869be-bab3-4204-94c3-1fc677f7d2de/resourcegroups/rgag/workspaces/wsag&tid=0f942ca0-ebef-4f26-80f8-f501d599ba90
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/09/06 07:01:03 Downloading source code...
# 2021/09/06 07:01:04 Finished downloading source code
# 2021/09/06 07:01:04 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/09/06 07:01:05 Successfully set up Docker network: acb_default_network
# 2021/09/06 07:01:05 Setting up Docker configuration...
# 2021/09/06 07:01:05 Successfully set up Docker configuration
# 2021/09/06 07:01:05 Logging in to registry: 1c8df59276a845b89d560f6ec57c4237.azurecr.io
# 2021/09/06 07:01:06 Successfully logged into 1c8df59276a845b89d560f6ec57c4237.azurecr.io
# 2021/09/06 07:01:06 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/06 07:01:06 Scanning for dependencies...
# 2021/09/06 07:01:07 Successfully scanned dependencies
# 2021/09/06 07:01:07 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1@sha256:4ecdbdb2fbc42ffe26c34a74464310318c8f212ef57e5fbd5373509e5fec533c
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1@sha256:4ecdbdb2fbc42ffe26c34a74464310318c8f212ef57e5fbd5373509e5fec533c: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 25fa05cd42bd: Pulling fs layer
# d919a1754444: Pulling fs layer
# 503f8e7b8f00: Pulling fs layer
# bdabc678f352: Pulling fs layer
# 032131447e0e: Pulling fs layer
# 2563f27cea79: Pulling fs layer
# 5d58346cd085: Pulling fs layer
# 9833a4023137: Pulling fs layer
# d709a6919501: Pulling fs layer
# bdabc678f352: Waiting
# 032131447e0e: Waiting
# 2563f27cea79: Waiting
# 5d58346cd085: Waiting
# 9833a4023137: Waiting
# d709a6919501: Waiting
# 25fa05cd42bd: Verifying Checksum
# 25fa05cd42bd: Download complete
# 503f8e7b8f00: Verifying Checksum
# 503f8e7b8f00: Download complete
# bdabc678f352: Verifying Checksum
# bdabc678f352: Download complete
# d919a1754444: Verifying Checksum
# d919a1754444: Download complete
# 2563f27cea79: Verifying Checksum
# 2563f27cea79: Download complete
# 032131447e0e: Verifying Checksum
# 032131447e0e: Download complete
# 9833a4023137: Verifying Checksum
# 9833a4023137: Download complete
# 5d58346cd085: Verifying Checksum
# 5d58346cd085: Download complete
# 25fa05cd42bd: Pull complete
# d709a6919501: Download complete
# d919a1754444: Pull complete
# 503f8e7b8f00: Pull complete
# bdabc678f352: Pull complete
# 032131447e0e: Pull complete
# 2563f27cea79: Pull complete
# 5d58346cd085: Pull complete
# 9833a4023137: Pull complete
# d709a6919501: Pull complete
# Digest: sha256:4ecdbdb2fbc42ffe26c34a74464310318c8f212ef57e5fbd5373509e5fec533c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1@sha256:4ecdbdb2fbc42ffe26c34a74464310318c8f212ef57e5fbd5373509e5fec533c
#  ---> f5193fa1f6ad
# Step 2/18 : USER root
#  ---> Running in cd976a1bdeea
# Removing intermediate container cd976a1bdeea
#  ---> 4ce7aaac3dce
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 05a39ad06dec
# Removing intermediate container 05a39ad06dec
#  ---> c2edf96c064e
# Step 4/18 : WORKDIR /
#  ---> Running in c1cc72407040
# Removing intermediate container c1cc72407040
#  ---> d6863a9b6fbf
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 2df76bfe08b6
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in e6af2f46bd97
# Removing intermediate container e6af2f46bd97
#  ---> e2c4b23618b6
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 379b041d72ca
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 44459f6623b4
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# ca-certificates-2021 | 113 KB    |            |   0%
# ca-certificates-2021 | 113 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ##5        |  26%
# python-3.6.2         | 23.6 MB   | ######5    |  65%
# python-3.6.2         | 23.6 MB   | ########## | 100%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# intel-openmp-2021.3. | 1.4 MB    |            |   0%
# intel-openmp-2021.3. | 1.4 MB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# setuptools-52.0.0    | 724 KB    |            |   0%
# setuptools-52.0.0    | 724 KB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | #####5     |  56%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 6          |   7%
# mkl-2020.2           | 138.3 MB  | #5         |  16%
# mkl-2020.2           | 138.3 MB  | ##5        |  25%
# mkl-2020.2           | 138.3 MB  | ###4       |  35%
# mkl-2020.2           | 138.3 MB  | ####4      |  45%
# mkl-2020.2           | 138.3 MB  | #####4     |  54%
# mkl-2020.2           | 138.3 MB  | ######4    |  64%
# mkl-2020.2           | 138.3 MB  | #######3   |  74%
# mkl-2020.2           | 138.3 MB  | ########3  |  83%
# mkl-2020.2           | 138.3 MB  | #########2 |  93%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# wheel-0.37.0         | 32 KB     |            |   0%
# wheel-0.37.0         | 32 KB     | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.9xcr0aca.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.33.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core~=1.33.0
#   Downloading azureml_core-1.33.0.post1-py3-none-any.whl (2.2 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.33.0
#   Downloading azureml_dataset_runtime-1.33.0-py3-none-any.whl (3.5 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.9xcr0aca.requirements.txt (line 1)) (52.0.0.post20210125)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.7.13-py2.py3-none-any.whl (127 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting urllib3<=1.26.5,>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.18.0-py2.py3-none-any.whl (166 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-defaults->-r /azureml-environment-setup/condaenv.9xcr0aca.requirements.txt (line 1)) (1.16.0)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-dataprep<2.21.0a,>=2.20.0a
#   Downloading azureml_dataprep-2.20.1-py3-none-any.whl (39.4 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.33.0->azureml-defaults->-r /azureml-environment-setup/condaenv.9xcr0aca.requirements.txt (line 1)) (1.19.2)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex<1.19.0a,>=1.18.0dev0
#   Downloading azureml_dataprep_rslex-1.18.2-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.14.0-py2.py3-none-any.whl (75 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-defaults->-r /azureml-environment-setup/condaenv.9xcr0aca.requirements.txt (line 1)) (2021.5.30)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting google-api-core<2.0.0,>=1.0.0
#   Downloading google_api_core-1.31.2-py2.py3-none-any.whl (93 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.17.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting google-auth<2.0dev,>=1.25.0
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Collecting packaging>=14.3
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Building wheels for collected packages: json-logging-py, fusepy, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=02404e20bb6d8f5c5c9cf5f5d6cfb53c4db6608b9e91cc87555e3ffd2ede95d3
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=31de7daa06c871cfcf6436157abaf4adfb58a182b7b5b71d4738b3cf370732a9
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=bb1f08d5fc9dd9914085feaa48165b040a92ab4f9e21f4ef83097aec8bf94876
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, typing-extensions, pyasn1, portalocker, oauthlib, msal, rsa, requests-oauthlib, python-dateutil, pyparsing, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, zipp, pytz, packaging, msrest, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, websocket-client, ruamel.yaml.clib, pyopenssl, pyarrow, opencensus-context, msrestazure, MarkupSafe, jeepney, importlib-metadata, google-api-core, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, werkzeug, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, jsonpickle, jmespath, Jinja2, itsdangerous, fusepy, docker, contextlib2, click, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, opencensus-ext-azure, json-logging-py, gunicorn, flask, configparser, azureml-core, applicationinsights, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.18.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.33.0.post1 azureml-dataprep-2.20.1 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.18.2 azureml-dataset-runtime-1.33.0 azureml-defaults-1.33.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.2 cffi-1.14.6 charset-normalizer-2.0.4 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-4.4.4 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 google-api-core-1.31.2 google-auth-1.35.0 googleapis-common-protos-1.53.0 gunicorn-20.1.0 idna-3.2 immutables-0.16 importlib-metadata-4.8.1 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.14.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 opencensus-0.7.13 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 packaging-21.0 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.17.3 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-2.4.7 python-dateutil-2.8.2 pytz-2021.1 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.5 websocket-client-1.2.1 werkzeug-1.0.1 zipp-3.5.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 44459f6623b4
#  ---> a469050bde3f
# Step 9/18 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in b9c4238a79e8
# Removing intermediate container b9c4238a79e8
#  ---> 4ee616614c69
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> b88846c870dd
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> d392ef696867
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in ca89b8b668c3
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container ca89b8b668c3
#  ---> bc5e8c86c47f
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in d674c532c0c0
# Removing intermediate container d674c532c0c0
#  ---> d7185f0f16df
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in 0e4cc19d37aa
# Removing intermediate container 0e4cc19d37aa
#  ---> 623bbe17cdd8
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 9001dbf7d295
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 6bf7b23d8c4f
# Removing intermediate container 6bf7b23d8c4f
#  ---> 364342883017
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in ff8f82af33f8
# Removing intermediate container ff8f82af33f8
#  ---> e3b4f2c59a2e
# Step 18/18 : CMD ["bash"]
#  ---> Running in 9a5454c2f873
# Removing intermediate container 9a5454c2f873
#  ---> 9fce89b69544
# Successfully built 9fce89b69544
# Successfully tagged 1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72:latest
# Successfully tagged 1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72:1
# 2021/09/06 07:02:58 Successfully executed container: acb_step_0
# 2021/09/06 07:02:58 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/06 07:02:58 Pushing image: 1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72:1, attempt 1
# The push refers to repository [1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72]
# dc612051008f: Preparing
# 2d253b6d6a78: Preparing
# 5e18280f6b8a: Preparing
# e5ae987d2b89: Preparing
# f61c3ab5a53a: Preparing
# 56b9b23f35f0: Preparing
# e8b80fb0c6b2: Preparing
# a1bb3e0cf498: Preparing
# 7780e7dbf7ce: Preparing
# a44c2175ce16: Preparing
# 8ed2835b4e11: Preparing
# 3236194bab08: Preparing
# 4cce4df42af8: Preparing
# 1b260ce6c815: Preparing
# 346bf99f5c59: Preparing
# cc59b450fe4b: Preparing
# 9f7d6b46eb7d: Preparing
# 8f8f0266f834: Preparing
# 56b9b23f35f0: Waiting
# e8b80fb0c6b2: Waiting
# a1bb3e0cf498: Waiting
# 7780e7dbf7ce: Waiting
# a44c2175ce16: Waiting
# 8ed2835b4e11: Waiting
# 3236194bab08: Waiting
# 4cce4df42af8: Waiting
# 1b260ce6c815: Waiting
# 346bf99f5c59: Waiting
# cc59b450fe4b: Waiting
# 9f7d6b46eb7d: Waiting
# 8f8f0266f834: Waiting
# e5ae987d2b89: Pushed
# 5e18280f6b8a: Pushed
# dc612051008f: Pushed
# 2d253b6d6a78: Pushed
# 56b9b23f35f0: Pushed
# e8b80fb0c6b2: Pushed
# a1bb3e0cf498: Pushed
# 7780e7dbf7ce: Pushed
# a44c2175ce16: Pushed
# 8ed2835b4e11: Pushed
# 3236194bab08: Pushed
# 4cce4df42af8: Pushed
# 346bf99f5c59: Pushed
# cc59b450fe4b: Pushed
# 1b260ce6c815: Pushed
# 8f8f0266f834: Pushed
# 9f7d6b46eb7d: Pushed
# f61c3ab5a53a: Pushed
# 1: digest: sha256:f656739effe9698ed38dc6af23bef42380c08d267d635bdcca45b2d284ed232f size: 4099
# 2021/09/06 07:04:41 Successfully pushed image: 1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72:1
# 2021/09/06 07:04:41 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/06 07:04:41 Pushing image: 1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72:latest, attempt 1
# The push refers to repository [1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72]
# dc612051008f: Preparing
# 2d253b6d6a78: Preparing
# 5e18280f6b8a: Preparing
# e5ae987d2b89: Preparing
# f61c3ab5a53a: Preparing
# 56b9b23f35f0: Preparing
# e8b80fb0c6b2: Preparing
# a1bb3e0cf498: Preparing
# 7780e7dbf7ce: Preparing
# a44c2175ce16: Preparing
# 8ed2835b4e11: Preparing
# 3236194bab08: Preparing
# 4cce4df42af8: Preparing
# 1b260ce6c815: Preparing
# 346bf99f5c59: Preparing
# cc59b450fe4b: Preparing
# 9f7d6b46eb7d: Preparing
# 8f8f0266f834: Preparing
# 56b9b23f35f0: Waiting
# e8b80fb0c6b2: Waiting
# a1bb3e0cf498: Waiting
# 7780e7dbf7ce: Waiting
# a44c2175ce16: Waiting
# 8ed2835b4e11: Waiting
# 3236194bab08: Waiting
# 4cce4df42af8: Waiting
# 1b260ce6c815: Waiting
# 346bf99f5c59: Waiting
# cc59b450fe4b: Waiting
# 9f7d6b46eb7d: Waiting
# 8f8f0266f834: Waiting
# 2d253b6d6a78: Layer already exists
# f61c3ab5a53a: Layer already exists
# e5ae987d2b89: Layer already exists
# 5e18280f6b8a: Layer already exists
# dc612051008f: Layer already exists
# a1bb3e0cf498: Layer already exists
# 7780e7dbf7ce: Layer already exists
# 8ed2835b4e11: Layer already exists
# 3236194bab08: Layer already exists
# a44c2175ce16: Layer already exists
# 4cce4df42af8: Layer already exists
# 1b260ce6c815: Layer already exists
# 346bf99f5c59: Layer already exists
# cc59b450fe4b: Layer already exists
# 9f7d6b46eb7d: Layer already exists
# 8f8f0266f834: Layer already exists
# 56b9b23f35f0: Layer already exists
# e8b80fb0c6b2: Layer already exists
# latest: digest: sha256:f656739effe9698ed38dc6af23bef42380c08d267d635bdcca45b2d284ed232f size: 4099
# 2021/09/06 07:04:43 Successfully pushed image: 1c8df59276a845b89d560f6ec57c4237.azurecr.io/azureml/azureml_0bef94ec66a3edd2493292aee0d9de72:latest
# 2021/09/06 07:04:43 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 111.468373)
# 2021/09/06 07:04:43 Populating digests for step ID: acb_step_0...
# 2021/09/06 07:04:44 Successfully populated digests for step ID: acb_step_0
# 2021/09/06 07:04:44 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 102.575868)
# 2021/09/06 07:04:44 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.229042)
# 2021/09/06 07:04:44 The following dependencies were found:
# 2021/09/06 07:04:44
# - image:
#     registry: 1c8df59276a845b89d560f6ec57c4237.azurecr.io
#     repository: azureml/azureml_0bef94ec66a3edd2493292aee0d9de72
#     tag: latest
#     digest: sha256:f656739effe9698ed38dc6af23bef42380c08d267d635bdcca45b2d284ed232f
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210714.v1
#     digest: sha256:4ecdbdb2fbc42ffe26c34a74464310318c8f212ef57e5fbd5373509e5fec533c
#   git: {}
# - image:
#     registry: 1c8df59276a845b89d560f6ec57c4237.azurecr.io
#     repository: azureml/azureml_0bef94ec66a3edd2493292aee0d9de72
#     tag: "1"
#     digest: sha256:f656739effe9698ed38dc6af23bef42380c08d267d635bdcca45b2d284ed232f
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210714.v1
#     digest: sha256:4ecdbdb2fbc42ffe26c34a74464310318c8f212ef57e5fbd5373509e5fec533c
#   git: {}
#
# Run ID: cr1 was successful after 3m42s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_96e1d8ba8e86fd83945af8357d476514b59147aba73bb57bde79949bba577a11_d.txt
# ========================================================================================================================
# 2021-09-06T07:09:45Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24796 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-09-06T07:09:45Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/mounts/workspaceblobstore
# 2021-09-06T07:09:46Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-06T07:09:46Z Starting output-watcher...
# 2021-09-06T07:09:46Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-09-06T07:09:47Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-09-06T07:09:47Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-09-06T07:09:47Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2021-09-06T07:09:48Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1e5b59c0734bdc528077f509e1d397fe
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 886c27cf0865: Pulling fs layer
# 7c9062f12448: Pulling fs layer
# 7268e886f68a: Pulling fs layer
# e1fdaab561c7: Pulling fs layer
# ccb2816215bd: Pulling fs layer
# 55d70b17f345: Pulling fs layer
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 886c27cf0865: Waiting
# 7c9062f12448: Waiting
# 7268e886f68a: Waiting
# e1fdaab561c7: Waiting
# ccb2816215bd: Waiting
# 55d70b17f345: Waiting
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# fb52bde70123: Download complete
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 7268e886f68a: Verifying Checksum
# 7268e886f68a: Download complete
# e1fdaab561c7: Verifying Checksum
# e1fdaab561c7: Download complete
# ccb2816215bd: Verifying Checksum
# ccb2816215bd: Download complete
# 886c27cf0865: Verifying Checksum
# 886c27cf0865: Download complete
# 55d70b17f345: Verifying Checksum
# 55d70b17f345: Download complete
# 92473f7ef455: Pull complete
# 7c9062f12448: Verifying Checksum
# 7c9062f12448: Download complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 886c27cf0865: Pull complete
# 7c9062f12448: Pull complete
# 7268e886f68a: Pull complete
# e1fdaab561c7: Pull complete
# ccb2816215bd: Pull complete
# 55d70b17f345: Pull complete
# Digest: sha256:d0c5e40cf440c619e721faa614dc94fe56cb6c41768532d169421cbe2288edc7
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_1e5b59c0734bdc528077f509e1d397fe:latest
# viennaglobal.azurecr.io/azureml/azureml_1e5b59c0734bdc528077f509e1d397fe:latest
# 2021-09-06T07:10:24Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-06T07:10:24Z Check if container 326a23de-f2a6-4093-bd2c-52b4b1f3fff2_DataSidecar already exist exited with 0,
#
# 3b76091636434850bac7c4897f945693657cae1a61dd44289dd14233213ef84f
# 2021-09-06T07:10:25Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-09-06T07:10:25Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-ef3318f11d3b20efb7e8ac9d06575cc5-74eb9e063b645bf8-01 -sshRequired=false]
# 2021/09/06 07:10:25 Starting App Insight Logger for task:  containerSetup
# 2021/09/06 07:10:25 Version: 3.0.01695.0004 Branch: .SourceBranch Commit: d8186cb
# 2021/09/06 07:10:25 Entered ContainerSetupTask - Preparing infiniband
# 2021/09/06 07:10:25 Starting infiniband setup
# 2021/09/06 07:10:25 Python Version found is Python 3.7.9
#
# 2021/09/06 07:10:25 Returning Python Version as 3.7
# 2021/09/06 07:10:25 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/09/06 07:10:25 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-09-06T07:10:25Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/09/06 07:10:25 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/09/06 07:10:25 Not setting up Infiniband in Container
# 2021/09/06 07:10:25 Not setting up Infiniband in Container
# 2021-09-06T07:10:25Z Not setting up Infiniband in Container
# 2021/09/06 07:10:25 Python Version found is Python 3.7.9
#
# 2021/09/06 07:10:25 Returning Python Version as 3.7
# 2021/09/06 07:10:25 sshd inside container not required for job, skipping setup.
# 2021/09/06 07:10:26 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/09/06 07:10:26 App Insight Client has already been closed
# 2021/09/06 07:10:26 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-09-06T07:10:26Z Starting docker container succeeded.
# 2021-09-06T07:10:26Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# Streaming azureml-logs/65_job_prep-tvmps_96e1d8ba8e86fd83945af8357d476514b59147aba73bb57bde79949bba577a11_d.txt
# ===============================================================================================================
# [2021-09-06T07:10:27.816555] Entering job preparation.
# [2021-09-06T07:10:28.373973] Starting job preparation.
# [2021-09-06T07:10:28.374021] Extracting the control code.
# [2021-09-06T07:10:28.374714] Starting extract_project.
# [2021-09-06T07:10:28.374966] Starting to extract zip file.
# [2021-09-06T07:10:28.390906] Finished extracting zip file.
# [2021-09-06T07:10:28.394960] Using urllib.request Python 3.0 or later
# [2021-09-06T07:10:28.395137] Start fetching snapshots.
# [2021-09-06T07:10:28.395288] Start fetching snapshot.
# [2021-09-06T07:10:28.395308] Retrieving project from snapshot: db544c33-63c5-4288-a309-f21153759d76
# Starting the daemon thread to refresh tokens in background for process with pid = 60
# [2021-09-06T07:10:28.843248] Finished fetching snapshot.
# [2021-09-06T07:10:28.843281] Start fetching snapshot.
# [2021-09-06T07:10:28.843298] Retrieving project from snapshot: 1423572d-4a9f-4849-a6ad-33363c2622a6
# [2021-09-06T07:10:34.528328] Finished fetching snapshot.
# [2021-09-06T07:10:34.528363] Finished fetching snapshots.
# [2021-09-06T07:10:34.528424] Finished extract_project.
# [2021-09-06T07:10:34.528608] Finished fetching and extracting the control code.
# [2021-09-06T07:10:34.536413] Start run_history_prep.
# [2021-09-06T07:10:34.543013] Job preparation is complete.
# [2021-09-06T07:10:34.543284] Entering Data Context Managers in Sidecar
# [2021-09-06T07:10:34.544153] Running Sidecar prep cmd...
# [2021-09-06T07:10:34.960925] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2
# [2021-09-06T07:10:34.961946] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.32.0 azureml-dataprep==2.20.1. Session id: 6333079e-278c-4758-8f70-f7aed2225724. Run id: 326a23de-f2a6-4093-bd2c-52b4b1f3fff2.
# Processing 'diabetes_batch'.
# Mode: 'mount'.
# Path on compute is specified: 'False'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "2930b901-6bef-47df-95c0-ab2fc8f89e9d",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='wsag', subscription_id='6ea869be-bab3-4204-94c3-1fc677f7d2de', resource_group='rgag')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/diabetes_batch_2930b901-6bef-47df-95c0-ab2fc8f89e9d.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/diabetes_batch_2930b901-6bef-47df-95c0-ab2fc8f89e9d as folder.
# Processing 'inferences'.
# Mode: 'mount'.
# Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/inferences_workspaceblobstore'.
# Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/inferences_workspaceblobstore.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/diabetes_batch_2930b901-6bef-47df-95c0-ab2fc8f89e9d
# Set OutputDataset inferences's target path to /tmp/5d39832e-5a00-4d6f-94a5-e500f187bc01
# [2021-09-06T07:10:50.262333] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-09-06T07:10:50.514990] Ran Sidecar prep cmd.
# [2021-09-06T07:10:50.515084] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/09/06 07:11:38 Starting App Insight Logger for task:  runTaskLet
# 2021/09/06 07:11:38 Version: 3.0.01695.0004 Branch: .SourceBranch Commit: d8186cb
# 2021/09/06 07:11:38 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/09/06 07:11:38 Send process info logs to master server succeeded
# 2021/09/06 07:11:38 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/09/06 07:11:38 Send process info logs to master server succeeded
# [2021-09-06T07:11:38.280910] Entering context manager injector.
# [2021-09-06T07:11:38.778076] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.33.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2021-09-06T07:11:38.782055] Entering Run History Context Manager.
# [2021-09-06T07:11:39.430028] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2
# [2021-09-06T07:11:39.430062] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.33.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'diabetes_batch']
# [2021-09-06T07:11:39.430081] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.33.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/tmp/5d39832e-5a00-4d6f-94a5-e500f187bc01', '--input_fds_0', 'diabetes_batch']
#
# 2021/09/06 07:11:43 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#
# [2021-09-06T07:12:36.057430] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 3 items cleaning up...
# Cleanup took 0.14771819114685059 seconds
# [2021-09-06T07:12:36.316755] Finished context manager injector.
# 2021/09/06 07:12:37 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/09/06 07:12:37 Send process info logs to master server succeeded
# 2021/09/06 07:12:37 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/09/06 07:12:37 Process Exiting with Code:  0
# 2021/09/06 07:12:38 All App Insights Logs was sent successfully or the close timeout of 10 was reached
#
# Streaming azureml-logs/75_job_post-tvmps_96e1d8ba8e86fd83945af8357d476514b59147aba73bb57bde79949bba577a11_d.txt
# ===============================================================================================================
# [2021-09-06T07:12:39.215589] Entering job release
# [2021-09-06T07:12:40.033715] Starting job release
# [2021-09-06T07:12:40.034397] Logging experiment finalizing status in history service.[2021-09-06T07:12:40.034614] job release stage : upload_datastore starting...
#
# Starting the daemon thread to refresh tokens in background for process with pid = 366
# [2021-09-06T07:12:40.038297] Entering context manager injector.
# [2021-09-06T07:12:40.042607] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-09-06T07:12:40.042761] job release stage : execute_job_release starting...
# [2021-09-06T07:12:40.046536] job release stage : upload_datastore completed...
# [2021-09-06T07:12:40.046678] job release stage : copy_batchai_cached_logs starting...
# [2021-09-06T07:12:40.047966] job release stage : copy_batchai_cached_logs completed...
# [2021-09-06T07:12:40.136273] job release stage : send_run_telemetry starting...
# [2021-09-06T07:12:40.156628] get vm size and vm region successfully.
# [2021-09-06T07:12:40.172699] get compute meta data successfully.
# [2021-09-06T07:12:40.280281] job release stage : execute_job_release completed...
# [2021-09-06T07:12:40.309206] post artifact meta request successfully.
# [2021-09-06T07:12:40.332422] upload compute record artifact successfully.
# [2021-09-06T07:12:40.332516] job release stage : send_run_telemetry completed...
# [2021-09-06T07:12:40.333112] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-09-06T07:12:40.333327] Running Sidecar release cmd...
# [2021-09-06T07:12:40.344533] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/diabetes_batch_2930b901-6bef-47df-95c0-ab2fc8f89e9d.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/diabetes_batch_2930b901-6bef-47df-95c0-ab2fc8f89e9d: Invalid argument
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/diabetes_batch_2930b901-6bef-47df-95c0-ab2fc8f89e9d.
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/inferences_workspaceblobstore.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/wsag/azureml/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/wd/inferences_workspaceblobstore.
# Exit __exit__ of DatasetContextManager
# [2021-09-06T07:12:40.392116] Removing absolute paths from host...
# [2021-09-06T07:12:40.393389] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-09-06T07:12:40.760393] Ran Sidecar release cmd.
# [2021-09-06T07:12:40.760512] Job release is complete
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '326a23de-f2a6-4093-bd2c-52b4b1f3fff2', 'target': 'agcluster', 'status': 'Completed', 'startTimeUtc': '2021-09-06T07:09:40.074147Z', 'endTimeUtc': '2021-09-06T07:13:21.139313Z', 'properties': {'ContentSnapshotId': 'db544c33-63c5-4288-a309-f21153759d76', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'e3e3e332-61b9-4c4f-a2e1-7af760d268fd', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '7f1e08d1', 'azureml.pipelinerunid': 'a4786afb-5e0a-4b07-8b96-36aa53b5b350', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '2930b901-6bef-47df-95c0-ab2fc8f89e9d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}, {'dataset': {'id': 'ee02bb46-c0f1-4d68-94b6-3a04b4af7536'}, 'consumptionDetails': {'type': 'Reference'}}], 'outputDatasets': [{'identifier': {'savedId': 'ee02bb46-c0f1-4d68-94b6-3a04b4af7536'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/326a23de-f2a6-4093-bd2c-52b4b1f3fff2/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "ee02bb46-c0f1-4d68-94b6-3a04b4af7536",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='wsag', subscription_id='6ea869be-bab3-4204-94c3-1fc677f7d2de', resource_group='rgag')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.33.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'agcluster', 'dataReferences': {}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '2930b901-6bef-47df-95c0-ab2fc8f89e9d', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': '/tmp/5d39832e-5a00-4d6f-94a5-e500f187bc01/', 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2021-09-06T07:00:48Z_ac14be01', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults']}], 'name': 'azureml_e220b045f6c3c3008b1a386af067185d'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210714.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': [], 'dataBricks': {'workers': 0, 'minimumWorkerCount': 0, 'maxMumWorkerCount': 0, 'sparkVersion': '4.0.x-scala2.11', 'nodeTypeId': 'Standard_D3_v2', 'sparkConf': {}, 'sparkEnvVars': {}, 'ins ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'a4786afb-5e0a-4b07-8b96-36aa53b5b350', 'status': 'Completed', 'startTimeUtc': '2021-09-06T07:00:06.70969Z', 'endTimeUtc': '2021-09-06T07:13:23.829865Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://wsag5167136068.blob.core.windows.net/azureml/ExperimentRun/dcid.a4786afb-5e0a-4b07-8b96-36aa53b5b350/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=ANmmclm4cuE2fB%2FropLhZOYyTGzNN%2F6h3djo31zT1sM%3D&st=2021-09-06T07%3A03%3A32Z&se=2021-09-06T15%3A13%3A32Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://wsag5167136068.blob.core.windows.net/azureml/ExperimentRun/dcid.a4786afb-5e0a-4b07-8b96-36aa53b5b350/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Ga%2FWv8AvVf12UJrFxDpYR15ix1fAWloHJ7YPQANZvec%3D&st=2021-09-06T07%3A03%3A32Z&se=2021-09-06T15%3A13%3A32Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://wsag5167136068.blob.core.windows.net/azureml/ExperimentRun/dcid.a4786afb-5e0a-4b07-8b96-36aa53b5b350/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=M4XjuEGJkk4SmNciLgC7QdlpiTgY6v8GfayTe%2BCHXpw%3D&st=2021-09-06T07%3A03%3A32Z&se=2021-09-06T15%3A13%3A32Z&sp=r'}, 'submittedBy': 'Ambarish Ganguly'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           1
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           0
# 5    13.csv           0
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           0
# 10   18.csv           0
# 11   19.csv           0
# 12    2.csv           0
# 13   20.csv           0
# 14   21.csv           1
# 15   22.csv           0
# 16   23.csv           1
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           0

# %%
prediction_run
# Out:
# Run(Experiment: mslearn-diabetes-batch,
# Id: 326a23de-f2a6-4093-bd2c-52b4b1f3fff2,
# Type: azureml.StepRun,
# Status: Completed)

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 625ed935-fb74-4259-90e5-a19cd108ba9e,
# Status: Active,
# Endpoint: https://australiaeast.api.azureml.ms/pipelines/v1.0/subscriptions/6ea869be-bab3-4204-94c3-1fc677f7d2de/resourceGroups/rgag/providers/Microsoft.MachineLearningServices/workspaces/wsag/PipelineRuns/PipelineSubmit/625ed935-fb74-4259-90e5-a19cd108ba9e)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://australiaeast.api.azureml.ms/pipelines/v1.0/subscriptions/6ea869be-bab3-4204-94c3-1fc677f7d2de/resourceGroups/rgag/providers/Microsoft.MachineLearningServices/workspaces/wsag/PipelineRuns/PipelineSubmit/625ed935-fb74-4259-90e5-a19cd108ba9e

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '60f025c2-e15b-4be3-8e7e-0cee5695fb6f'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 60f025c2-e15b-4be3-8e7e-0cee5695fb6f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/60f025c2-e15b-4be3-8e7e-0cee5695fb6f?wsid=/subscriptions/6ea869be-bab3-4204-94c3-1fc677f7d2de/resourcegroups/rgag/workspaces/wsag&tid=0f942ca0-ebef-4f26-80f8-f501d599ba90
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '60f025c2-e15b-4be3-8e7e-0cee5695fb6f', 'status': 'Completed', 'startTimeUtc': '2021-09-06T07:31:53.06468Z', 'endTimeUtc': '2021-09-06T07:31:55.248997Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': '625ed935-fb74-4259-90e5-a19cd108ba9e'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://wsag5167136068.blob.core.windows.net/azureml/ExperimentRun/dcid.60f025c2-e15b-4be3-8e7e-0cee5695fb6f/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=QisctqCvsqfVE9RAUuT5LN46ZJeYMaGJVErTdeoO5to%3D&st=2021-09-06T07%3A22%3A10Z&se=2021-09-06T15%3A32%3A10Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://wsag5167136068.blob.core.windows.net/azureml/ExperimentRun/dcid.60f025c2-e15b-4be3-8e7e-0cee5695fb6f/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=rjYuGKCx0dzjZ19yb84%2By11Af4U%2Fr94yelfiZBRcfBI%3D&st=2021-09-06T07%3A22%3A10Z&se=2021-09-06T15%3A32%3A10Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://wsag5167136068.blob.core.windows.net/azureml/ExperimentRun/dcid.60f025c2-e15b-4be3-8e7e-0cee5695fb6f/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=nD6rZj8DzYX0vX80mL70bX7XrXj2sSOwUd%2BgvyLW50A%3D&st=2021-09-06T07%3A22%3A10Z&se=2021-09-06T15%3A32%3A10Z&sp=r'}, 'submittedBy': 'Ambarish Ganguly'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           1
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           0
# 5    13.csv           0
# 6    14.csv           0
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           0
# 10   18.csv           0
# 11   19.csv           0
# 12    2.csv           0
# 13   20.csv           0
# 14   21.csv           1
# 15   22.csv           0
# 16   23.csv           1
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
